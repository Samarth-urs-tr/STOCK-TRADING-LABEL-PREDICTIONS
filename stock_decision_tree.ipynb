# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

df = pd.read_csv('NVDA_data.csv')
df.head()
# Out:
#    Year  Week_Number       Open  Adj Close  mean_return  volatility  \
# 0  2018            0  48.945000  53.287727      1.98875    3.081352
# 1  2018            1  55.099998  55.162941      0.70180    1.397675
# 2  2018            2  56.012501  56.926830      0.80200    1.813348
# 3  2018            3  57.607498  60.197319      1.13480    1.691356
# 4  2018            4  60.685001  57.770416     -0.80300    2.021694
#
#   color_label
# 0         red
# 1         red
# 2       green
# 3       green
# 4         red

# %%
train_data = df[df['Year'] != 2022].copy()
test_data = df[df['Year'] == 2022].copy()

X_train = train_data[['Open', 'Adj Close', 'mean_return', 'volatility']]
y_train = train_data['color_label']

X_test = test_data[['Open', 'Adj Close', 'mean_return', 'volatility']]
y_test_true = test_data['color_label']

# %%
# Decision Tree and its accuracy for Year 2
decision_tree = DecisionTreeClassifier(random_state=42)
decision_tree.fit(X_train, y_train)
y_test_pred_dt = decision_tree.predict(X_test)
accuracy_dt = accuracy_score(y_test_true, y_test_pred_dt)
print(f'Accuracy of Decision Tree for Year 2: {accuracy_dt}')

# confusion matrix for Decision Tree
conf_matrix_dt = confusion_matrix(y_test_true, y_test_pred_dt)
print('Confusion Matrix for Decision Tree (Year 2):')
print(conf_matrix_dt)

# sensitivity (recall) and specificity for Decision Tree
tn_dt, fp_dt, fn_dt, tp_dt = conf_matrix_dt.ravel()
sensitivity_dt = tp_dt / (tp_dt + fn_dt)
specificity_dt = tn_dt / (tn_dt + fp_dt)
print(f'True Positive Rate (Sensitivity) for Decision Tree: {sensitivity_dt:.4f}')
print(f'True Negative Rate (Specificity) for Decision Tree: {specificity_dt:.4f}')
# Out:
# Accuracy of Decision Tree for Year 2: 0.8846153846153846
# Confusion Matrix for Decision Tree (Year 2):
# [[12  2]
#  [ 4 34]]
# True Positive Rate (Sensitivity) for Decision Tree: 0.8947
# True Negative Rate (Specificity) for Decision Tree: 0.8571

# %%
test_data['predicted_label'] = y_test_pred_dt
test_data.head()
# Out:
#      Year  Week_Number        Open   Adj Close  mean_return  volatility  \
# 211  2022            1  298.149994  272.118683      -1.4652    3.573360
# 212  2022            2  265.809998  269.072632      -0.1934    2.768013
# 213  2022            3  262.600006  233.438583      -3.4885    0.320452
# 214  2022            4  223.300003  228.105469      -0.4078    3.646720
# 215  2022            5  231.820007  242.876404       1.3404    4.416611
#
#     color_label predicted_label
# 211         red             red
# 212         red             red
# 213         red             red
# 214         red             red
# 215       green           green

# %% [markdown]
# # Trading strategy for 2022 to calculate the amount at the end of the year using predicted labels

# %%
def trading_strategy_predicted_logistic_reg(df, initial_balance=100):
    df = df.reset_index(drop=True)  # Reset the index to numeric values
    balance = initial_balance
    position = None
    balance_history = []

    for week in range(len(df)):  # Adjust the loop condition
        open_price = df.loc[week, 'Open']
        close_price = df.loc[week, 'Adj Close']

        if df.loc[week, 'predicted_label'] == 'green':
            if position is None:
                shares_to_buy = balance / open_price
                print(f"Week {week}: Buying {shares_to_buy:.2f} shares at ${open_price:.2f}")
                position = shares_to_buy
                balance = 0
                print(f"   Shares: {position:.2f}, Portfolio Value: ${balance:.2f}")

        elif df.loc[week, 'predicted_label'] == 'red':
            if position is not None:
                balance_from_selling = position * df.loc[week - 1, 'Adj Close']
                print(f"Week {week}: Selling {position:.2f} shares at ${df.loc[week - 1, 'Adj Close']:.2f}, "
                      f"Portfolio Value: ${balance_from_selling:.2f}")
                balance += balance_from_selling
                position = None
                print(f"   Portfolio Value: ${balance:.2f}")

        if position is None:
            portfolio_value = balance
        else:
            portfolio_value = position * df.loc[week - 1, 'Adj Close']

        balance_history.append(portfolio_value)
        print(f"Week {week}: Portfolio Value: ${portfolio_value:.2f}")

    return balance_history

resulting_balance_history_lr = trading_strategy_predicted_logistic_reg(test_data)
print("Balance History based on Modified Predicted Labels for 2022:", resulting_balance_history_lr[-1])
# Out:
# Week 0: Portfolio Value: $100.00
# Week 1: Portfolio Value: $100.00
# Week 2: Portfolio Value: $100.00
# Week 3: Portfolio Value: $100.00
# Week 4: Buying 0.43 shares at $231.82
#    Shares: 0.43, Portfolio Value: $0.00
# Week 4: Portfolio Value: $98.40
# Week 5: Selling 0.43 shares at $242.88, Portfolio Value: $104.77
#    Portfolio Value: $104.77
# Week 5: Portfolio Value: $104.77
# Week 6: Portfolio Value: $104.77
# Week 7: Portfolio Value: $104.77
# Week 8: Portfolio Value: $104.77
# Week 9: Portfolio Value: $104.77
# Week 10: Buying 0.48 shares at $218.69
#    Shares: 0.48, Portfolio Value: $0.00
# Week 10: Portfolio Value: $105.76
# Week 11: Selling 0.48 shares at $264.23, Portfolio Value: $126.59
#    Portfolio Value: $126.59
# Week 11: Portfolio Value: $126.59
# Week 12: Portfolio Value: $126.59
# Week 13: Portfolio Value: $126.59
# Week 14: Portfolio Value: $126.59
# Week 15: Portfolio Value: $126.59
# Week 16: Portfolio Value: $126.59
# Week 17: Buying 0.68 shares at $185.41
#    Shares: 0.68, Portfolio Value: $0.00
# Week 17: Portfolio Value: $126.49
# Week 18: Selling 0.68 shares at $186.54, Portfolio Value: $127.36
#    Portfolio Value: $127.36
# Week 18: Portfolio Value: $127.36
# Week 19: Portfolio Value: $127.36
# Week 20: Buying 0.78 shares at $162.74
#    Shares: 0.78, Portfolio Value: $0.00
# Week 20: Portfolio Value: $130.50
# Week 21: Selling 0.78 shares at $187.90, Portfolio Value: $147.05
#    Portfolio Value: $147.05
# Week 21: Portfolio Value: $147.05
# Week 22: Portfolio Value: $147.05
# Week 23: Portfolio Value: $147.05
# Week 24: Buying 0.89 shares at $164.75
#    Shares: 0.89, Portfolio Value: $0.00
# Week 24: Portfolio Value: $141.61
# Week 25: Selling 0.89 shares at $171.10, Portfolio Value: $152.72
#    Portfolio Value: $152.72
# Week 25: Portfolio Value: $152.72
# Week 26: Buying 1.08 shares at $141.75
#    Shares: 1.08, Portfolio Value: $0.00
# Week 26: Portfolio Value: $156.33
# Week 27: Selling 1.08 shares at $158.24, Portfolio Value: $170.48
#    Portfolio Value: $170.48
# Week 27: Portfolio Value: $170.48
# Week 28: Buying 1.05 shares at $163.02
#    Shares: 1.05, Portfolio Value: $0.00
# Week 28: Portfolio Value: $164.69
# Week 29: Selling 1.05 shares at $173.03, Portfolio Value: $180.96
#    Portfolio Value: $180.96
# Week 29: Portfolio Value: $180.96
# Week 30: Buying 1.00 shares at $181.82
#    Shares: 1.00, Portfolio Value: $0.00
# Week 30: Portfolio Value: $180.60
# Week 31: Selling 1.00 shares at $189.72, Portfolio Value: $188.82
#    Portfolio Value: $188.82
# Week 31: Portfolio Value: $188.82
# Week 32: Portfolio Value: $188.82
# Week 33: Portfolio Value: $188.82
# Week 34: Portfolio Value: $188.82
# Week 35: Buying 1.38 shares at $137.31
#    Shares: 1.38, Portfolio Value: $0.00
# Week 35: Portfolio Value: $187.49
# Week 36: Selling 1.38 shares at $143.78, Portfolio Value: $197.72
#    Portfolio Value: $197.72
# Week 36: Portfolio Value: $197.72
# Week 37: Portfolio Value: $197.72
# Week 38: Portfolio Value: $197.72
# Week 39: Portfolio Value: $197.72
# Week 40: Portfolio Value: $197.72
# Week 41: Buying 1.72 shares at $115.18
#    Shares: 1.72, Portfolio Value: $0.00
# Week 41: Portfolio Value: $192.60
# Week 42: Portfolio Value: $213.86
# Week 43: Portfolio Value: $237.33
# Week 44: Portfolio Value: $242.85
# Week 45: Selling 1.72 shares at $163.17, Portfolio Value: $280.09
#    Portfolio Value: $280.09
# Week 45: Portfolio Value: $280.09
# Week 46: Buying 1.85 shares at $151.47
#    Shares: 1.85, Portfolio Value: $0.00
# Week 46: Portfolio Value: $284.76
# Week 47: Portfolio Value: $300.68
# Week 48: Portfolio Value: $311.96
# Week 49: Selling 1.85 shares at $169.95, Portfolio Value: $314.27
#    Portfolio Value: $314.27
# Week 49: Portfolio Value: $314.27
# Week 50: Portfolio Value: $314.27
# Week 51: Portfolio Value: $314.27
# Balance History based on Modified Predicted Labels for 2022: 314.2661891384986
